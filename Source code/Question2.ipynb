# %% [markdown]
# #### **Installation of packages**
# ###### In our assignment, we implement the installation of gmplot and ortools in assisting us to compute the shortest path distance from the distribution center to all stores in the country as mentioned in the question given.

# %%
# Uncomment and install all the requirements before proceed
# !pip install gmplot
# !pip install ortools
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gmplot
#   Downloading gmplot-1.4.1-py3-none-any.whl (164 kB)
#      |████████████████████████████████| 164 kB 7.5 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from gmplot) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->gmplot) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->gmplot) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->gmplot) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->gmplot) (1.24.3)
# Installing collected packages: gmplot
# Successfully installed gmplot-1.4.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ortools
#   Downloading ortools-9.3.10497-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.5 MB)
#      |████████████████████████████████| 15.5 MB 8.4 MB/s
# Requirement already satisfied: absl-py>=0.13 in /usr/local/lib/python3.7/dist-packages (from ortools) (1.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from ortools) (1.21.6)
# Collecting protobuf>=3.19.4
#   Downloading protobuf-4.21.1-cp37-abi3-manylinux2014_x86_64.whl (407 kB)
#      |████████████████████████████████| 407 kB 64.8 MB/s
# Installing collected packages: protobuf, ortools
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.2+zzzcolab20220527125636 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.21.1 which is incompatible.
# tensorflow-metadata 1.8.0 requires protobuf<4,>=3.13, but you have protobuf 4.21.1 which is incompatible.
# googleapis-common-protos 1.56.2 requires protobuf<4.0.0dev,>=3.15.0, but you have protobuf 4.21.1 which is incompatible.
# google-cloud-bigquery-storage 1.1.2 requires protobuf<4.0.0dev, but you have protobuf 4.21.1 which is incompatible.
# google-api-core 1.31.6 requires protobuf<4.0.0dev,>=3.12.0; python_version > "3", but you have protobuf 4.21.1 which is incompatible.
# Successfully installed ortools-9.3.10497 protobuf-4.21.1

# %% [markdown]
# #### **Import Libraries**
# ######We found it useful in implementing gmplot module sourced from the Google Maps API to scatter pointers and plot routes accordingly based on the optimal distribution path with the lowest cost calculated. For better file management, we mounted google drive in which necessary datasets and files are needed or being written to.

# %%
import numpy as np
import pandas as pd
import requests
import json
import gmplot
import itertools
from typing_extensions import OrderedDict

# %%
from google.colab import drive

# at this point, an additional confirmation is needed before you switch linking to the desired google drive instead of the previous linked account
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### **Requirement to use Google API**

# %%
#API Key to be used later
API_KEY = "AIzaSyAGAkRtsWsQmDWgVI_dWeF8VvQw5EdhyUA"
base_url = "https://maps.googleapis.com/maps/api/distancematrix/json?"

# %% [markdown]
# #### **Importing and obtaining data**
# ######Datasets are retrieved from the *.csv* file provided via the google drive where the file is uploaded.

# %%
# change to the your own T1G7- Algo directory
data = pd.read_csv("/content/drive/MyDrive/Algo/starbucks_2018_11_06.csv")

# %%
data.head()
# Out:
#                                name  \
# 0           Musashisakai Ito Yokado
# 1                   LUMINE Fujisawa
# 2                             Aarau
# 3  Abbotsford Hospital - main lobby
# 4    Mt. Lehman Centre - Abbotsford
#
#                                                  url        street address  \
# 0  https://www.starbucks.com/store-locator/store/...      2-3-6, Kyonancho
# 1  https://www.starbucks.com/store-locator/store/...       438-1 Fujisawa,
# 2  https://www.starbucks.com/store-locator/store/...          Kasinogarten
# 3  https://www.starbucks.com/store-locator/store/794     32900 Marshall Rd
# 4  https://www.starbucks.com/store-locator/store/...  3250 Mt. Lehman Road
#
#               city state   latitude   longitude
# 0  2-3-6 Kyonancho    JP  35.701179  139.544735
# 1   438-1 Fujisawa    JP  35.338851  139.487219
# 2            Aarau    CH  47.392177    8.046180
# 3       Abbotsford    CA  49.036926 -122.311545
# 4       Abbotsford    CA  49.061388 -122.380708

# %% [markdown]
# At this point, we may retrieve the data that we request from the *.csv* file.

# %%
# INSERT THE CITY HERE

country = data[data['state']=='US']

#randomly take 6 stores 
stores = country.sample(n=6)

# sourced: Pandas DataFrame.reset_index() which resets index of a Data Frame.
# inplace: make changes in the original data frame itself if True.
# drop: add the replaced index column to the data if False. 
stores.reset_index(inplace=True,drop=True)

stores
# Out:
#                           name  \
# 0              Touhy & Central
# 1  Target Colo Springs ST-2221
# 2                   34th & 7th
# 3      Blossom Hill & Winfield
# 4           Rookwood Pavillion
# 5                 UNC Hospital
#
#                                                  url         street address  \
# 0  https://www.starbucks.com/store-locator/store/...         5720 Touhy Ave
# 1  https://www.starbucks.com/store-locator/store/...   9670 Promenent Point
# 2  https://www.starbucks.com/store-locator/store/...         450 7th Avenue
# 3  https://www.starbucks.com/store-locator/store/...  967 Blossom Hill Road
# 4  https://www.starbucks.com/store-locator/store/...        2692 Madison Rd
# 5  https://www.starbucks.com/store-locator/store/...         101 Manning Dr
#
#                city state   latitude   longitude
# 0             Niles    US  42.012551  -87.770536
# 1  Colorado Springs    US  38.954600 -104.768000
# 2          New York    US  40.751373  -73.990982
# 3          San Jose    US  37.250701 -121.865926
# 4        Cincinnati    US  39.147498  -84.443065
# 5       Chapel Hill    US  35.903968  -79.049392

# %% [markdown]
# #### **Compute Distance Matrix**

# %%
# iloc() function in Pandas module selects a particular cell of dataset that is selecting value that belongs to a particular row or column from a set of values of a data frame of a dataset.

def calculate_distance_matrix(stores):
    distance_matrix = [] 
    for i in range(len(stores)):
        ori = stores.iloc[i]
        des_list = []
        for j in range(len(stores)):
            des = stores.iloc[j]
            #update the parameter to be passed into distance matrix
            param = {
                'origins' :str(ori['latitude'])+","+ str(ori['longitude']),  # pair up first location latitude and logitude
                'destinations' : str(des['latitude'])+","+ str(des['longitude']), # pair up second location latitude and logitude
                'mode' : 'driving',
                'key' : API_KEY
            }
            
            response = requests.get(base_url, params = param)
            r = response.json()
            des_list.append(r['rows'][0]['elements'][0]['distance']['value']) 
            # only get the distance between the 2 points
        distance_matrix.append(des_list)
    return distance_matrix

# %%
distance_matrix = calculate_distance_matrix(stores)

distance_matrix

# if random stores located is China, probably will have error 'KeyError: distance' etc
# Out:
# [[0, 1718052, 1294042, 3500719, 501574, 1278016],
#  [1716055, 0, 2896849, 2134458, 1886905, 2611507],
#  [1293609, 2856417, 0, 4747308, 1019768, 803381],
#  [3494500, 2136471, 4742133, 0, 3903594, 4453666],
#  [501419, 1891089, 1023043, 3913216, 0, 814490],
#  [1277657, 2613105, 802274, 4453055, 814367, 0]]

# %% [markdown]
# #### **Find distribution center**
#
# Calculating the optimal path from the distribution center to all stores available in the country.

# %%
# concept
# find local distribution center, the location having shortest total distance from all point is the center

def find_distribution_center(distance_matrix):
  cost = {}

  for i in range(len(distance_matrix)):
      name = stores['name'].iloc[i]
      total_distance= 0
      for x in distance_matrix[i]:
          total_distance +=x
        
      cost[name]=total_distance
    
  center = min(cost, key=cost.get)  
  # getting the store which has min length from all stores as the distribution center
  distribution_center = stores[stores['name']==center]  # retrieving info from dataset on distribution center

  center_index = distribution_center.index[0]
  print(center)
  # rearrange data so that distribution center is at the first index
  b, c = stores.iloc[0].copy(), stores.iloc[center_index].copy()
  stores.iloc[0],stores.iloc[center_index] = c,b
  distribution_center = stores[stores.index==0]

  return distribution_center

# %%
distribution_center = find_distribution_center(distance_matrix)
distribution_center
# Out:
# Rookwood Pavillion
#                  name                                                url  \
# 0  Rookwood Pavillion  https://www.starbucks.com/store-locator/store/...
#
#     street address        city state   latitude  longitude
# 0  2692 Madison Rd  Cincinnati    US  39.147498 -84.443065

# %% [markdown]
# #### **Traveling Salesman Problem (TSP) using Held-Karp Algorithm**
#
# Explanation about the algorithm : https://youtu.be/-JjA4BLQyqE
#
# Another video source: https://www.youtube.com/watch?v=jUYAJ72m8P0

# %%
# dynamic programming with memoization

def held_karp(dists):
    
    n = len(dists)

    # Maps each subset of the nodes to the cost to reach that subset, as well
    # as what node it passed before reaching this subset.
    # Node subsets are represented as set bits.
    # format in C : '(Set bit,Subset),(Cost,Parent)'
    C = {}

    # Set transition cost from initial state
    for k in range(1, n):
        C[(1 << k, k)] = (dists[0][k], 0)
    
    # Iterate subsets of increasing length and store intermediate results
    # in classic dynamic programming manner
    for subset_size in range(2, n):
        for subset in itertools.combinations(range(1, n), subset_size):
            
            # Set bits for all nodes in this subset
            # we encode each set into binary
            # eg : {0,3,4} = 11001
            bits = 0
            for bit in subset:
                bits |= 1 << bit

            # Find the lowest cost to get to this subset
            for k in subset:
                prev = bits & ~(1 << k)

                res = []
                for m in subset:
                    if m == 0 or m == k:
                        continue
                    res.append((C[(prev, m)][0] + dists[m][k], m))
                C[(bits, k)] = min(res)

    # We're interested in all bits but the least significant (the start state)
    bits = (2**n - 1) - 1

    # Calculate optimal cost
    res = []
    for k in range(1, n):
        res.append((C[(bits, k)][0] + dists[k][0], k))
    opt, parent = min(res) 

    # Backtrack to find full path
    path = []
    path.append(0)
    for i in range(n - 1):
        path.append(parent)
        new_bits = bits & ~(1 << parent)
        _, parent = C[(bits, parent)]
        bits = new_bits

    # Add implicit start state
    path.append(0)

    return opt, list(reversed(path))

# %%
shortest_distance, route = held_karp(distance_matrix)

print("Shortest path : ", route)
print("Total distance :  " ,shortest_distance, " miles")
# Out:
# Shortest path :  [0, 2, 5, 4, 1, 3, 0]
# Total distance :   10431837  miles

# %%
# plot using gm plot 

def gmplot_stores(stores,filename):
    
    map = gmplot.GoogleMapPlotter(float(distribution_center.latitude),float(distribution_center.longitude),4,apikey=API_KEY)

    # plot stores
    for i in range(len(stores)):
        s = stores.iloc[i]
        if i ==0:
          map.marker(s['latitude'],s['longitude'],color='red',label=i,info_window=s['name'])
        else:
          map.marker(s['latitude'],s['longitude'],color='blue',label=i,info_window="Center: " + s['name'])

    
    map.draw( "/content/drive/MyDrive/Algo/"+filename )

# %%
# plot using gm plot 

def gmplot_paths(stores,route,filename):
    
    map = gmplot.GoogleMapPlotter(float(distribution_center.latitude),float(distribution_center.longitude),4,apikey=API_KEY)

    # plot stores
    for i in range(len(stores)):
        s = stores.iloc[i]
        map.marker(s['latitude'],s['longitude'],color='blue',label=i,info_window=s['name'])
        
    # plot distribution center
    # map.marker(float(distribution_center.latitude),float(distribution_center.longitude),color='orange')
    

    #plot route
    #map.directions([float(distribution_center.latitude),float(distribution_center.longitude)],[float(stores.iloc[4]['latitude']),float(stores.iloc[4]['longitude'])],color='red')
    for i in range(len(route)-1):
        start_index = route[i]
        end_index = route[i+1]
        starting_point = [float(stores.iloc[start_index]['latitude']),float(stores.iloc[start_index]['longitude'])]
        end_point = [float(stores.iloc[end_index]['latitude']),float(stores.iloc[end_index]['longitude'])]
        map.directions(starting_point,end_point,color='black')
  
    map.draw( "/content/drive/MyDrive/Algo/"+filename )

# %% [markdown]
# #### **Display Plotted Map**
# ###### The function ***gmplot_map*** accepts parameters such as stores and route. Returns a html file, showing the plotted Google Maps to the user.

# %%
gmplot_paths(stores,route,"USmap.html")
#you can find the map in the T1G7-Algo folder, it will open up a html page

# %% [markdown]
# #### **Total distance for each country**

# %%
path_distance_dict ={}

# %% [markdown]
# ###**AR**

# %%
country_name = 'AR'
country = data[data['state']==country_name]
stores = country.sample(n=6)
stores.reset_index(inplace=True,drop=True)

# %%
stores
# Out:
#                      name                                                url  \
# 0  Abasto Shopping Center  https://www.starbucks.com/store-locator/store/148
# 1                  Elcano  https://www.starbucks.com/store-locator/store/153
# 2        Parque Rivadavia  https://www.starbucks.com/store-locator/store/...
# 3                Mansilla  https://www.starbucks.com/store-locator/store/...
# 4      Unicenter Shopping  https://www.starbucks.com/store-locator/store/...
# 5                Martinez  https://www.starbucks.com/store-locator/store/...
#
#                              street address          city state   latitude  \
# 0                   Corrientes Avenida 3247  Buenos Aires    AR -34.603912
# 1                               Elcano 3179  Buenos Aires    AR -34.572935
# 2                        Av. Rivadavia 4893  Buenos Aires    AR -34.617189
# 3      Av. Coronel Diaz 1601, esq. Mansilla  Buenos Aires    AR -34.592319
# 4                               Parana 3745      Martinez    AR -34.506768
# 5  Av del Libertador Gral. San Martin 13891      Martinez    AR -34.483377
#
#    longitude
# 0 -58.410938
# 1 -58.459374
# 2 -58.433990
# 3 -58.412618
# 4 -58.523491
# 5 -58.489665

# %%
distance_matrix = calculate_distance_matrix(stores)

distance_matrix
# Out:
# [[0, 6892, 3241, 1695, 23418, 21331],
#  [6918, 0, 6987, 6491, 10691, 11910],
#  [3647, 6930, 0, 4692, 29122, 32493],
#  [1750, 5958, 4022, 0, 18977, 16890],
#  [23483, 11005, 29060, 19121, 0, 4868],
#  [21215, 12135, 23955, 16853, 5036, 0]]

# %%
distribution_center = find_distribution_center(distance_matrix)
distribution_center
# Out:
# Elcano
#      name                                                url street address  \
# 0  Elcano  https://www.starbucks.com/store-locator/store/153    Elcano 3179
#
#            city state   latitude  longitude
# 0  Buenos Aires    AR -34.572935 -58.459374

# %%
gmplot_stores(stores,"ARmap.html")

# %%
shortest_distance, route = held_karp(distance_matrix)

print("Shortest path : ", route)
print("Total distance :  " ,shortest_distance, " miles")
# Out:
# Shortest path :  [0, 2, 1, 4, 5, 3, 0]
# Total distance :   44333  miles

# %%
path_distance_dict[country_name] = shortest_distance

gmplot_paths(stores,route,"AR_1map.html")
#you can find the map in the T1G7-Algo folder, it will open up a html page

# %% [markdown]
# ###**CN**

# %%
country_name = 'CN'
country = data[data['state']==country_name]
stores = country.sample(n=6)
stores.reset_index(inplace=True,drop=True)
stores
# Out:
#        name                                                url  \
# 0      新世界店  https://www.starbucks.com/store-locator/store/...
# 1  武汉徐东销品茂店  https://www.starbucks.com/store-locator/store/...
# 2    青岛佳世客店  https://www.starbucks.com/store-locator/store/...
# 3      大拇指店  https://www.starbucks.com/store-locator/store/...
# 4      虹梅路店  https://www.starbucks.com/store-locator/store/...
# 5    沈阳万象城店  https://www.starbucks.com/store-locator/store/...
#
#       street address city state   latitude   longitude
# 0           黄浦区, 新世界  上海市    CN  31.234909  121.473892
# 1            徐东大街18号  武汉市    CN  30.588724  114.342801
# 2            香港中路72号  青岛市    CN  36.063488  120.397809
# 3          浦东新区, 大拇指  上海市    CN  31.227702  121.558990
# 4             上海市闵行区  上海市    CN  31.188114  121.387444
# 5  和平区, 沈阳万象城负一层B105  沈阳市    CN  41.775010  123.434729

# %%
distance_matrix = calculate_distance_matrix(stores)
distribution_center = find_distribution_center(distance_matrix)
distribution_center
# Out:
# 虹梅路店
#    name                                                url street address  \
# 0  虹梅路店  https://www.starbucks.com/store-locator/store/...         上海市闵行区
#
#   city state   latitude   longitude
# 0  上海市    CN  31.188114  121.387444

# %%
distance_matrix
# Out:
# [[0, 835964, 725724, 9833, 11509, 1736464],
#  [835614, 0, 1123964, 853747, 825058, 1800312],
#  [725429, 1123186, 0, 734446, 727020, 1180223],
#  [21171, 852065, 733140, 0, 27609, 1743880],
#  [11614, 826548, 724803, 19636, 0, 1735544],
#  [1734914, 1798886, 1181594, 1743931, 1736505, 0]]

# %%
gmplot_stores(stores,"CNmap.html")

# %%
shortest_distance, route = held_karp(distance_matrix)

print("Shortest path : ", route)
print("Total distance :  " ,shortest_distance, " miles")
# Out:
# Shortest path :  [0, 3, 2, 5, 1, 4, 0]
# Total distance :   4558754  miles

# %%
path_distance_dict[country_name] = shortest_distance

gmplot_paths(stores,route,"CN_1map.html")
#you can find the map in the T1G7-Algo folder, it will open up a html page

# %% [markdown]
# ###**JP**

# %%
country_name = 'JP'

country = data[data['state']==country_name]
stores = country.sample(n=6)
stores.reset_index(inplace=True,drop=True)
stores
# Out:
#                                  name  \
# 0         AEON MALL Hamamatsu Shitoro
# 1            Utsunomiya Kamitomatsuri
# 2                      Kofu Alps-dori
# 3                       Shiki Eki-mae
# 4  Roppongi Hills METRO HAT/HOLLYWOOD
# 5                   Venus Fort Family
#
#                                                  url  \
# 0  https://www.starbucks.com/store-locator/store/...
# 1  https://www.starbucks.com/store-locator/store/...
# 2  https://www.starbucks.com/store-locator/store/...
# 3  https://www.starbucks.com/store-locator/store/...
# 4  https://www.starbucks.com/store-locator/store/...
# 5  https://www.starbucks.com/store-locator/store/...
#
#                     street address       city state   latitude   longitude
# 0          2-37-1 Shitoro Nishi-ku  Hamamatsu    JP  34.696465  137.652242
# 1  366-7 Kakenoue Kamitomatsuricho   Utsunomi    JP  36.587816  139.865102
# 2                59-12 Shimizuarai  Showa-cho    JP  35.650959  138.543269
# 3                    2-39-1 Tohoku      Niiza    JP  35.822814  139.574796
# 4                   6-4-1 Roppongi  Minato-ku    JP  35.661605  139.729537
# 5                      1-3-15 Aomi    Koto-ku    JP  35.625283  139.781222

# %%
distance_matrix = calculate_distance_matrix(stores)
distribution_center = find_distribution_center(distance_matrix)
distribution_center
# Out:
# Roppongi Hills METRO HAT/HOLLYWOOD
#                                  name  \
# 0  Roppongi Hills METRO HAT/HOLLYWOOD
#
#                                                  url  street address  \
# 0  https://www.starbucks.com/store-locator/store/...  6-4-1 Roppongi
#
#         city state   latitude   longitude
# 0  Minato-ku    JP  35.661605  139.729537

# %%
distance_matrix
# Out:
# [[0, 397904, 191380, 290389, 260759, 270439],
#  [398824, 0, 232728, 128415, 141600, 148923],
#  [190930, 231540, 0, 143139, 130778, 138791],
#  [290880, 127802, 143348, 0, 35380, 42298],
#  [260681, 143444, 128474, 36982, 0, 11986],
#  [269753, 147058, 138406, 41136, 8490, 0]]

# %%
gmplot_stores(stores,"JPmap.html")

# %%
shortest_distance, route = held_karp(distance_matrix)

print("Shortest path : ", route)
print("Total distance :  " ,shortest_distance, " miles")
# Out:
# Shortest path :  [0, 2, 1, 3, 5, 4, 0]
# Total distance :   862804  miles

# %%
path_distance_dict[country_name] = shortest_distance

gmplot_paths(stores,route,"JP_1map.html")
#you can find the map in the T1G7-Algo folder, it will open up a html page

# %% [markdown]
# ###**CA**

# %%
country_name = 'CA'

country = data[data['state']==country_name]
stores = country.sample(n=6)
stores.reset_index(inplace=True,drop=True)
stores
# Out:
#                              name  \
# 0               Eglinton & Warden
# 1                    20 Market Dr
# 2   Save-on-Foods - Fort McMurray
# 3                   Horseshoe Bay
# 4        Toronto General Hospital
# 5  Mariner Square, Campbell River
#
#                                                  url  \
# 0  https://www.starbucks.com/store-locator/store/753
# 1  https://www.starbucks.com/store-locator/store/952
# 2  https://www.starbucks.com/store-locator/store/334
# 3  https://www.starbucks.com/store-locator/store/733
# 4  https://www.starbucks.com/store-locator/store/...
# 5  https://www.starbucks.com/store-locator/store/778
#
#                 street address            city state   latitude   longitude
# 0    1900 Eglinton Avenue East     Scarborough    CA  43.726914  -79.293247
# 1              20 Market Drive          Milton    CA  43.523159  -79.899373
# 2                131 Signal Rd   Fort McMurray    CA  56.730356 -111.426777
# 3            3-6390 Bay Street  West Vancouver    CA  49.374281 -123.274119
# 4  585 University Avenue, R-16         Toronto    CA  43.658317  -79.389438
# 5          1400 Dogwood Street  Campbell River    CA  50.028915 -125.249709

# %%
distance_matrix = calculate_distance_matrix(stores)
distribution_center = find_distribution_center(distance_matrix)
distribution_center
# Out:
# Safeway #4918 200th, Langley
#                            name  \
# 0  Safeway #4918 200th, Langley
#
#                                                  url street address     city  \
# 0  https://www.starbucks.com/store-locator/store/366  6153 200th St  Langley
#
#   state   latitude   longitude
# 0    CA  49.114757 -122.670708

# %%
distance_matrix
# Out:
# [[0, 1418932, 47125, 64099, 4233004, 1147468],
#  [1426473, 0, 1410729, 1370284, 3059005, 284163],
#  [48764, 1404499, 0, 37656, 4193910, 1133035],
#  [64508, 1361729, 36994, 0, 4178987, 1090264],
#  [4226781, 3051799, 4188751, 4172770, 0, 3335169],
#  [1147282, 276106, 1131539, 1091093, 3334393, 0]]

# %%
gmplot_stores(stores,"CAmap.html")

# %%
shortest_distance, route = held_karp(distance_matrix)

print("Shortest path : ", route)
print("Total distance :  " ,shortest_distance, " miles")
# Out:
# Shortest path :  [0, 3, 5, 1, 4, 2, 0]
# Total distance :   8726989  miles

# %%
path_distance_dict[country_name] = shortest_distance

gmplot_paths(stores,route,"CA_1map.html")
#you can find the map in the T1G7-Algo folder, it will open up a html page

# %% [markdown]
# ###**US**

# %%
country_name = 'US'

country = data[data['state']==country_name]
stores = country.sample(n=6)
stores.reset_index(inplace=True,drop=True)
stores
# Out:
#                           name  \
# 0  AAFES/ FT STEWART /Exchange
# 1                  Farmingdale
# 2    Randalls-Round Rock #2636
# 3              Alexander Place
# 4       Silverado Plaza - Napa
# 5       Stevens Creek & DeAnza
#
#                                                  url  \
# 0  https://www.starbucks.com/store-locator/store/...
# 1  https://www.starbucks.com/store-locator/store/...
# 2  https://www.starbucks.com/store-locator/store/...
# 3  https://www.starbucks.com/store-locator/store/...
# 4  https://www.starbucks.com/store-locator/store/...
# 5  https://www.starbucks.com/store-locator/store/...
#
#                                   street address         city state  \
# 0                            Ft Stewart Exchange   Hinesville    US
# 1                                 10 Michael Ave  Farmingdale    US
# 2                        2051 Gattis School Road   Round Rock    US
# 3  7854 Alexander Promenade Pl., Bldg. H, Ste. 1      Raleigh    US
# 4                             663 Trancas Street         Napa    US
# 5                      20520A Stevens Creek Blvd    Cupertino    US
#
#     latitude   longitude
# 0  31.970300  -81.642800
# 1  40.727235  -73.424472
# 2  30.495019  -97.654379
# 3  35.912714  -78.780773
# 4  38.323901 -122.286952
# 5  37.321992 -122.032782

# %%
distance_matrix = calculate_distance_matrix(stores)
distribution_center = find_distribution_center(distance_matrix)
distribution_center
# Out:
# Randalls-Round Rock #2636
#                         name  \
# 0  Randalls-Round Rock #2636
#
#                                                  url           street address  \
# 0  https://www.starbucks.com/store-locator/store/...  2051 Gattis School Road
#
#          city state   latitude  longitude
# 0  Round Rock    US  30.495019 -97.654379

# %%
distance_matrix
# Out:
# [[0, 1403320, 1730608, 611157, 4405031, 4313123],
#  [1403902, 0, 2844816, 844200, 4706869, 4805792],
#  [1731013, 2844066, 0, 2105934, 2873155, 2781247],
#  [610557, 843223, 2106901, 0, 4560463, 4495227],
#  [4401823, 4700413, 2871484, 4587697, 0, 152276],
#  [4307817, 4799058, 2777477, 4493691, 153675, 0]]

# %%
shortest_distance, route = held_karp(distance_matrix)

print("Shortest path : ", route)
print("Total distance :  " ,shortest_distance, " miles")
# Out:
# Shortest path :  [0, 2, 5, 4, 1, 3, 0]
# Total distance :   10820700  miles

# %%
gmplot_stores(stores,"USmap.html")

# %%
path_distance_dict[country_name] = shortest_distance

gmplot_paths(stores,route,"US_1map.html")
#you can find the map in the T1G7-Algo folder, it will open up a html page

# %%
print(path_distance_dict)
# Out:
# {'AR': 44333, 'CN': 44333, 'CA': 8726989, 'US': 10820700}
